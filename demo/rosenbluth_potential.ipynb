# %% [markdown]
# # Potential Reconstruction in the Cylindrical Coordinate

# %%
import torch
from pyapes.core.geometry import Cylinder
from pyapes.core.mesh import Mesh

from pyrfp.training_data import RosenbluthPotentials_RZ, analytic_potentials_rz_cpu


mesh = Mesh(Cylinder[0:5, -5:5], None, [32, 64])

mnts_eq = torch.tensor(
    [1, 0, 1, 0, 3, 2, 8, 0, 2], dtype=mesh.dtype.float, device=mesh.device
)

RP_rz = RosenbluthPotentials_RZ(
    mesh,
    optimizer_config={
        "lr": 1.0,
        "max_iter": 200,
        "gtol": 1e-6,
        "xtol": 1e-6,
    },
    solver_config={
        "method": "bicgstab",
        "tol": 1e-8,
        "max_it": 1000,
        "report": False,
    },
)

pots_mnts = RP_rz.from_moments(mnts_eq)["pots"]

assert pots_mnts is not None

H_exact = analytic_potentials_rz_cpu(mesh.grid, mesh.grid, pots_mnts["pdf"], "H")
G_exact = analytic_potentials_rz_cpu(mesh.grid, mesh.grid, pots_mnts["pdf"], "G")

jac_H_exact = torch.gradient(H_exact, spacing=mesh.dx.tolist(), edge_order=2)
jac_G_exact = torch.gradient(G_exact, spacing=mesh.dx.tolist(), edge_order=2)
hess_G_exact = torch.gradient(jac_G_exact[0], spacing=mesh.dx.tolist(), edge_order=2) # for rr and rz not zz

from pymyplot import myplt as plt
from pymyplot.colors import TOLCmap

_, axes = plt.subplots(2, 6, figsize=(30/2.54, 12/2.54))
axes[0][0].plot(mesh.grid[0][:, 16], H_exact[:, 16], "ro", label="exact")
axes[0][0].plot(mesh.grid[0][:, 16], pots_mnts["H"][:, 16], "b-", label="computed")

axes[1][0].plot(mesh.grid[0][:, 16], G_exact[:, 16], "ro")
axes[1][0].plot(mesh.grid[0][:, 16], pots_mnts["G"][:, 16], "b-")

axes[0][1].contourf(mesh.grid[0], mesh.grid[1], H_exact, 20, cmap=TOLCmap.sunset())
axes[1][1].contourf(mesh.grid[0], mesh.grid[1], pots_mnts["H"], 20, cmap=TOLCmap.sunset())

axes[0][2].contourf(mesh.grid[0], mesh.grid[1], G_exact, 20, cmap=TOLCmap.sunset())
axes[1][2].contourf(mesh.grid[0], mesh.grid[1], pots_mnts["G"], 20, cmap=TOLCmap.sunset())

axes[0][3].contourf(mesh.grid[0], mesh.grid[1], jac_H_exact[0], 20, cmap=TOLCmap.sunset())
axes[1][3].contourf(mesh.grid[0], mesh.grid[1], pots_mnts["jacH"].r, 20, cmap=TOLCmap.sunset())

axes[0][4].contourf(mesh.grid[0], mesh.grid[1], jac_G_exact[0], 20, cmap=TOLCmap.sunset())
axes[1][4].contourf(mesh.grid[0], mesh.grid[1], pots_mnts["jacG"].r, 20, cmap=TOLCmap.sunset())

axes[0][5].contourf(mesh.grid[0], mesh.grid[1], hess_G_exact[0], 20, cmap=TOLCmap.sunset())
axes[1][5].contourf(mesh.grid[0], mesh.grid[1], pots_mnts["hessG"].rr, 20, cmap=TOLCmap.sunset())

plt.show()
# Out:
# [17:13:03] INFO     🚀 Computing Maximum Entropy Distribution  🚀 (pymaxed v 0.1.5)             ]8;id=965158;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py\training_data.py]8;;\:]8;id=104037;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py#96\96]8;;\
#            INFO     Target moment:  tensor([1., 0., 1., 0., 3., 2., 8., 0., 2.])               ]8;id=359505;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py\training_data.py]8;;\:]8;id=69407;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py#104\104]8;;\
#            INFO     Domain:  [0.0, -5.0] x [5.0, 5.0]                                          ]8;id=343397;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py\training_data.py]8;;\:]8;id=189973;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py#105\105]8;;\
#            INFO     Grid:  [32, 64]                                                            ]8;id=252291;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py\training_data.py]8;;\:]8;id=661483;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py#111\111]8;;\
#            INFO     Solving for MaxEd...                                                       ]8;id=134466;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py\training_data.py]8;;\:]8;id=188585;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py#123\123]8;;\
#            INFO     🔥Done in 0.22 s                                                           ]8;id=584737;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py\training_data.py]8;;\:]8;id=724079;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py#127\127]8;;\
#            INFO     🚀 Computing Rosenbluth potentials s🚀 (pyrfp v 0.1.0)                     ]8;id=988013;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py\training_data.py]8;;\:]8;id=983651;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py#170\170]8;;\
#            INFO     Domain:  [0.0, -5.0] x [5.0, 5.0]                                          ]8;id=907589;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py\training_data.py]8;;\:]8;id=825372;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py#178\178]8;;\
#            INFO     Grid:  [32, 64]                                                            ]8;id=538872;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py\training_data.py]8;;\:]8;id=974243;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py#184\184]8;;\
#            INFO     Evaluating H potential boundary...                                         ]8;id=52583;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py\training_data.py]8;;\:]8;id=654951;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py#185\185]8;;\
#            INFO     🔥Done in 0.01 s                                                           ]8;id=337618;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py\training_data.py]8;;\:]8;id=821862;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py#189\189]8;;\
#            INFO     Solving H potential...                                                     ]8;id=854506;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py\training_data.py]8;;\:]8;id=256130;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py#196\196]8;;\
#            INFO     🔥Done in 0.05 s                                                           ]8;id=407158;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py\training_data.py]8;;\:]8;id=845230;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py#201\201]8;;\
#            INFO     Evaluating G potential boundary...                                         ]8;id=943757;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py\training_data.py]8;;\:]8;id=173260;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py#206\206]8;;\
#            INFO     🔥Done in 0.01 s                                                           ]8;id=145866;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py\training_data.py]8;;\:]8;id=796507;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py#210\210]8;;\
#            INFO     Solving G potential...                                                     ]8;id=858077;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py\training_data.py]8;;\:]8;id=163148;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py#217\217]8;;\
#            INFO     🔥Done in 0.06 s                                                           ]8;id=513065;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py\training_data.py]8;;\:]8;id=735106;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py#222\222]8;;\
#            INFO     H: successful, G: successful                                               ]8;id=153882;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py\training_data.py]8;;\:]8;id=778639;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py#227\227]8;;\
#            INFO     🎉 Finish! 🎉                                                              ]8;id=110259;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py\training_data.py]8;;\:]8;id=216887;file:///Users/kchung/Dropbox/Personal/python_projects/pyrfp/pyrfp/training_data.py#239\239]8;;\
